# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.listdir('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# ['hw2 (2).ipynb',
#  'hw2 (1).ipynb',
#  'hw2.ipynb',
#  'exam1_王昱鈞.ipynb',
#  'HW1_王昱鈞.ipynb',
#  'HW2_王昱鈞.ipynb',
#  'HW4_詹凱錞.ipynb',
#  'Untitled (2)',
#  'HW3_王昱鈞.ipynb',
#  'HW5_.ipynb',
#  'exam2_王昱鈞.ipynb',
#  'HW4_王昱鈞.ipynb',
#  'hw6',
#  'HW6_王昱鈞.ipynb',
#  'hw7 (1).ipynb',
#  'HW6_王昱鈞1.ipynb',
#  'hw7_.ipynb',
#  'Untitled (1)',
#  'HW7_李松鴻 (2).ipynb',
#  'HW6_詹凱錞.ipynb',
#  'CH6.ipynb',
#  'exam3_.ipynb',
#  'HW7_李松鴻 (1).ipynb',
#  'exam3_王昱鈞.ipynb',
#  'Untitled',
#  'HW7_李松鴻.ipynb',
#  'HW2 (1).ipynb',
#  'HW5_王昱鈞.ipynb',
#  'hw7.ipynb',
#  'HW7_王昱鈞.ipynb',
#  'HW8_李松鴻.ipynb',
#  'HW8_王昱鈞.ipynb',
#  'HW2.ipynb',
#  'Readme.ipynb',
#  'hw9.ipynb',
#  'Lasso.ipynb']

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/Medicalpremium.csv') #read csv file

# %% [markdown]
# # EDA
# ## 檢視表格資料及空值檢查

# %%
df.head()
# Out:
#    Age  Diabetes  ...  NumberOfMajorSurgeries  PremiumPrice
# 0   45         0  ...                       0         25000
# 1   60         1  ...                       0         29000
# 2   36         1  ...                       1         23000
# 3   52         1  ...                       2         28000
# 4   38         0  ...                       1         23000
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 各欄位介紹 (1:有, 0:無)
# ---
# Age ：年齡
# Diabetes : 是否患有糖尿病
# BloodPressureProblems : 是否血壓有異常問題
# AnyTransplants : 是否經歷過主要器官移植手術
# AnyChronicDiseases : 是否患有哮喘等慢性疾病
# Height : 身高,	Weight : 體重
# KnownAllergies : 是否有任何已知的過敏症
# HistoryOfCancerInFamily : 任何血緣親屬是否患有任何形式的癌症
# NumberOfMajorSurgeries : 該人接受過的大手術次數
# PremiumPrice : 年保費價格
#
#
#
# ---

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
df.describe()
# Out:
#               Age    Diabetes  ...  NumberOfMajorSurgeries  PremiumPrice
# count  986.000000  986.000000  ...              986.000000    986.000000
# mean    41.745436    0.419878  ...                0.667343  24336.713996
# std     13.963371    0.493789  ...                0.749205   6248.184382
# min     18.000000    0.000000  ...                0.000000  15000.000000
# 25%     30.000000    0.000000  ...                0.000000  21000.000000
# 50%     42.000000    0.000000  ...                1.000000  23000.000000
# 75%     53.000000    1.000000  ...                1.000000  28000.000000
# max     66.000000    1.000000  ...                3.000000  40000.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# 新增BMI欄位

# %%
#compute BMI
df["BMI"] = df.Weight/(df.Height/100)**2
df["BMI"] = pd.to_numeric(pd.cut(df['BMI'], bins=[0,24,27,30,35,100], labels=[0,1,2,3,4]))

# %% [markdown]
# # 檢視PremiumPrice分布

# %%
sns.displot(df.PremiumPrice, kde=True)
plt.title("PremiumPrice")
plt.show()

# %% [markdown]
# ## 畫出個欄位的Correlation heap map

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# 根據Correlation heap map 的圖表，選出與PremiumPrice相關性大於0.2之欄位做EDA
# (Age, AnyTransplants, AnyChronicDiseases, NumberOfMajorSurgeries)

# %%
sns.pairplot(df, vars = ["Age", "PremiumPrice"], hue = "AnyTransplants")
plt.show()

# %%
sns.pairplot(df, vars = ["Age", "PremiumPrice"], hue = "AnyChronicDiseases")
plt.show()

# %%
sns.pairplot(df, vars = ["Age", "PremiumPrice"], hue = "NumberOfMajorSurgeries")
plt.show()

# %% [markdown]
# 畫出三個連續性欄位的關聯分布及對應的PremiumPrice label

# %%
sns.pairplot(df, vars = ["Age", "Height", "Weight"], hue = "PremiumPrice")
plt.show()

# %% [markdown]
# 由上述之EDA可看出，
#
# *   年齡是影響PremiumPrice的主要因子, 但身高及體重似乎較無關聯
# *   是否經歷過主要器官移植手術也會使得PremiumPrice需要付出相當大的金額
# *   該人接受過的大手術次數與PremiumPrice有明顯的分布差異
# ---

# %% [markdown]
# 由於年齡與PremiumPrice高度相關，在這邊再創一個欄位代表幼年、青年、壯年、老年，以增加模型對於年齡的權重。

# %%
df["Age_new"]=pd.to_numeric(pd.cut(df["Age"],bins=[0,20,40,65,100], labels = [0,1,2,3]))

# %% [markdown]
# # Model select & training
# ## 1.選擇模型

# %%
from sklearn.linear_model import Ridge,Lasso,LinearRegression
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import GridSearchCV,RepeatedStratifiedKFold
from xgboost import XGBClassifier
from sklearn.metrics import explained_variance_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
PremiumPrice = labelencoder.fit_transform(df.PremiumPrice)
df_x = df.drop(columns = ["PremiumPrice"])
xtr,xte,ytr,yte=train_test_split(df_x,PremiumPrice,random_state=33,test_size=0.2, shuffle = True)

# %%
models=[('KNN',KNeighborsClassifier()),('DT',DecisionTreeClassifier()),('RF',RandomForestClassifier()),('AdaBoost',AdaBoostClassifier())
        ,('GP',GaussianProcessClassifier()),('NB',GaussianNB()),('XGB',XGBClassifier())]
scores=[]

for name,model in models:
    model.fit(xtr,ytr)
    preds=model.predict(xte)
    score=explained_variance_score(preds,yte)
    scores.append([name,model,score])

# %%
scores_df=pd.DataFrame(scores,columns=['Name','Model','Score'])
scores_df.sort_values('Score',ascending=False)
# Out:
#        Name                                              Model      Score
# 2        RF  (DecisionTreeClassifier(max_features='auto', r...   0.863417
# 6       XGB          XGBClassifier(objective='multi:softprob')   0.825311
# 1        DT                           DecisionTreeClassifier()   0.675841
# 0       KNN                             KNeighborsClassifier()   0.503548
# 4        GP                        GaussianProcessClassifier()   0.479142
# 5        NB                                       GaussianNB()  -2.088827
# 3  AdaBoost  (DecisionTreeClassifier(max_depth=1, random_st... -33.254638

# %% [markdown]
# 由上表選定最高的explained_variance_score為RandomForest model,因此選定為模型進行grid search最佳化參數

# %%
from sklearn.model_selection import GridSearchCV
classfier=RandomForestClassifier (n_jobs=-1,verbose=2)
param_grid={'n_estimators':[500,300,100],
            'max_depth':[7,8,9,10],
            'min_samples_split':[3,4,5],
            'max_features':['auto']}
gs=GridSearchCV(classfier,param_grid=param_grid,cv=3,n_jobs=-1,verbose=1)
gs.fit(xtr,ytr)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   UserWarning,
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.1s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100building tree 4 of 100
#
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100building tree 12 of 100
#
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100building tree 22 of 100
#
# building tree 23 of 100building tree 24 of 100
#
# building tree 25 of 100building tree 26 of 100
#
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100building tree 47 of 100
#
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100building tree 55 of 100
#
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100building tree 78 of 100
#
# building tree 79 of 100building tree 80 of 100
#
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100building tree 90 of 100
#
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100building tree 95 of 100
#
# building tree 96 of 100
# building tree 97 of 100building tree 98 of 100
#
# building tree 99 of 100building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_jobs=-1, verbose=2),
#              n_jobs=-1,
#              param_grid={'max_depth': [7, 8, 9, 10], 'max_features': ['auto'],
#                          'min_samples_split': [3, 4, 5],
#                          'n_estimators': [500, 300, 100]},
#              verbose=1)

# %%
pre = gs.predict(xte)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(pre, yte)
print(f"best accuracy(RandomForest model) = {accuracy:2.2f}")
# Out:
# best accuracy(RandomForest model) = 0.93

# %% [markdown]
# 最後RandomForest之Accuracy高達0.93

# %%
#compute BMI
df["BMI"] = df.Weight/(df.Height/100)**2
sns.displot(df.BMI)
sns.displot(df.BMI,bins=[0,18.5,24,27,30,35,df.BMI.max()])
df["BMI"] = pd.to_numeric(pd.cut(df['BMI'], bins=[0,18.5,24,27,30,35,df.BMI.max()], labels=[0,1,2,3,4,5]))

# %%
sns.displot(df.PremiumPrice, kde=True)
plt.title("PremiumPrice")
sns.displot(df.PremiumPrice, bins=[df.PremiumPrice.min(), 20000, 24000, 29000, 35000, df.PremiumPrice.max()], kde=True)
plt.title("PremiumPrice_bin5")
plt.show()
df['PremiumLabel'] = pd.to_numeric(pd.cut(df['PremiumPrice'], bins=[df.PremiumPrice.min()-1, 19000, 24000, 29000, 35000, df.PremiumPrice.max()], labels=[0,1,2,3,4]))

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()
df_x = df.drop(columns = ["PremiumLabel", "PremiumPrice"])
PremiumPrice = labelencoder.fit_transform(df.PremiumLabel)
PremiumPrice=onehotencoder.fit_transform(np.array(PremiumPrice).reshape(-1, 1)).toarray()
xtr_dnn,xte_dnn,ytr_dnn,yte_dnn=train_test_split(df_x,PremiumPrice,random_state=33,test_size=0.2, shuffle = True)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import ModelCheckpoint, EarlyStopping

filepath = "/content/drive/MyDrive/Colab Notebooks/best.hdf5"
model = Sequential()
model.add(Dense(units=16, input_dim=xtr_dnn.shape[1], kernel_initializer='normal', activation='relu')) 
model.add(Dense(units=8, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=ytr_dnn.shape[1], kernel_initializer='normal',activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer="adam" , metrics=['accuracy'])

checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
earlystopper = EarlyStopping(monitor='val_accuracy', patience=2000, verbose=1)
callbacks_list = [checkpoint, earlystopper]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                208
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 5)                 45
#
# =================================================================
# Total params: 389
# Trainable params: 389
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_history = model.fit(x=xtr_dnn, y=ytr_dnn, validation_split=0.3, epochs=10000, batch_size=800, verbose=2, shuffle=True, callbacks=callbacks_list)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
# Epoch 03156: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3508 - accuracy: 0.9020 - val_loss: 0.5820 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3157/10000
#
# Epoch 03157: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3508 - accuracy: 0.9020 - val_loss: 0.5827 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3158/10000
#
# Epoch 03158: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3508 - accuracy: 0.9002 - val_loss: 0.5825 - val_accuracy: 0.8565 - 52ms/epoch - 52ms/step
# Epoch 3159/10000
#
# Epoch 03159: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3508 - accuracy: 0.9020 - val_loss: 0.5824 - val_accuracy: 0.8565 - 43ms/epoch - 43ms/step
# Epoch 3160/10000
#
# Epoch 03160: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3508 - accuracy: 0.8984 - val_loss: 0.5826 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3161/10000
#
# Epoch 03161: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3507 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3162/10000
#
# Epoch 03162: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9002 - val_loss: 0.5824 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3163/10000
#
# Epoch 03163: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9020 - val_loss: 0.5824 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3164/10000
#
# Epoch 03164: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3165/10000
#
# Epoch 03165: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9002 - val_loss: 0.5822 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3166/10000
#
# Epoch 03166: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3167/10000
#
# Epoch 03167: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9020 - val_loss: 0.5819 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3168/10000
#
# Epoch 03168: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9020 - val_loss: 0.5830 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3169/10000
#
# Epoch 03169: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9002 - val_loss: 0.5820 - val_accuracy: 0.8565 - 52ms/epoch - 52ms/step
# Epoch 3170/10000
#
# Epoch 03170: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9002 - val_loss: 0.5825 - val_accuracy: 0.8565 - 42ms/epoch - 42ms/step
# Epoch 3171/10000
#
# Epoch 03171: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8565 - 41ms/epoch - 41ms/step
# Epoch 3172/10000
#
# Epoch 03172: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9002 - val_loss: 0.5815 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3173/10000
#
# Epoch 03173: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9020 - val_loss: 0.5825 - val_accuracy: 0.8565 - 40ms/epoch - 40ms/step
# Epoch 3174/10000
#
# Epoch 03174: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.9002 - val_loss: 0.5811 - val_accuracy: 0.8565 - 27ms/epoch - 27ms/step
# Epoch 3175/10000
#
# Epoch 03175: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.9020 - val_loss: 0.5832 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3176/10000
#
# Epoch 03176: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3506 - accuracy: 0.8984 - val_loss: 0.5816 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3177/10000
#
# Epoch 03177: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3178/10000
#
# Epoch 03178: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9002 - val_loss: 0.5825 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3179/10000
#
# Epoch 03179: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9020 - val_loss: 0.5813 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 3180/10000
#
# Epoch 03180: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9002 - val_loss: 0.5826 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3181/10000
#
# Epoch 03181: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9002 - val_loss: 0.5816 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3182/10000
#
# Epoch 03182: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.9020 - val_loss: 0.5831 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3183/10000
#
# Epoch 03183: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3504 - accuracy: 0.8984 - val_loss: 0.5823 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3184/10000
#
# Epoch 03184: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3503 - accuracy: 0.9020 - val_loss: 0.5824 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3185/10000
#
# Epoch 03185: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9002 - val_loss: 0.5826 - val_accuracy: 0.8565 - 52ms/epoch - 52ms/step
# Epoch 3186/10000
#
# Epoch 03186: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9002 - val_loss: 0.5817 - val_accuracy: 0.8565 - 29ms/epoch - 29ms/step
# Epoch 3187/10000
#
# Epoch 03187: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9020 - val_loss: 0.5826 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3188/10000
#
# Epoch 03188: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9002 - val_loss: 0.5819 - val_accuracy: 0.8565 - 28ms/epoch - 28ms/step
# Epoch 3189/10000
#
# Epoch 03189: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9020 - val_loss: 0.5833 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3190/10000
#
# Epoch 03190: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.8984 - val_loss: 0.5824 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3191/10000
#
# Epoch 03191: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9020 - val_loss: 0.5827 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3192/10000
#
# Epoch 03192: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9002 - val_loss: 0.5826 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3193/10000
#
# Epoch 03193: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9020 - val_loss: 0.5818 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3194/10000
#
# Epoch 03194: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9020 - val_loss: 0.5827 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3195/10000
#
# Epoch 03195: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9002 - val_loss: 0.5818 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3196/10000
#
# Epoch 03196: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.9020 - val_loss: 0.5835 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3197/10000
#
# Epoch 03197: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3502 - accuracy: 0.8984 - val_loss: 0.5823 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3198/10000
#
# Epoch 03198: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9020 - val_loss: 0.5828 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3199/10000
#
# Epoch 03199: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3500 - accuracy: 0.9002 - val_loss: 0.5827 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3200/10000
#
# Epoch 03200: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9002 - val_loss: 0.5817 - val_accuracy: 0.8565 - 40ms/epoch - 40ms/step
# Epoch 3201/10000
#
# Epoch 03201: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3500 - accuracy: 0.9020 - val_loss: 0.5829 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3202/10000
#
# Epoch 03202: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9002 - val_loss: 0.5818 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3203/10000
#
# Epoch 03203: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3500 - accuracy: 0.9020 - val_loss: 0.5834 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3204/10000
#
# Epoch 03204: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.8984 - val_loss: 0.5825 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3205/10000
#
# Epoch 03205: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9020 - val_loss: 0.5836 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3206/10000
#
# Epoch 03206: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3500 - accuracy: 0.9002 - val_loss: 0.5821 - val_accuracy: 0.8565 - 42ms/epoch - 42ms/step
# Epoch 3207/10000
#
# Epoch 03207: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3208/10000
#
# Epoch 03208: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3498 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3209/10000
#
# Epoch 03209: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9002 - val_loss: 0.5816 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3210/10000
#
# Epoch 03210: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9020 - val_loss: 0.5839 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3211/10000
#
# Epoch 03211: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.8984 - val_loss: 0.5821 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3212/10000
#
# Epoch 03212: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.9038 - val_loss: 0.5843 - val_accuracy: 0.8523 - 51ms/epoch - 51ms/step
# Epoch 3213/10000
#
# Epoch 03213: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3500 - accuracy: 0.9002 - val_loss: 0.5819 - val_accuracy: 0.8565 - 24ms/epoch - 24ms/step
# Epoch 3214/10000
#
# Epoch 03214: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3498 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3215/10000
#
# Epoch 03215: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.9002 - val_loss: 0.5824 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3216/10000
#
# Epoch 03216: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3498 - accuracy: 0.9002 - val_loss: 0.5814 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3217/10000
#
# Epoch 03217: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9038 - val_loss: 0.5841 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3218/10000
#
# Epoch 03218: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3501 - accuracy: 0.8984 - val_loss: 0.5819 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3219/10000
#
# Epoch 03219: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.9038 - val_loss: 0.5833 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3220/10000
#
# Epoch 03220: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.9002 - val_loss: 0.5824 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3221/10000
#
# Epoch 03221: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3496 - accuracy: 0.9002 - val_loss: 0.5817 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3222/10000
#
# Epoch 03222: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.9020 - val_loss: 0.5831 - val_accuracy: 0.8523 - 31ms/epoch - 31ms/step
# Epoch 3223/10000
#
# Epoch 03223: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3498 - accuracy: 0.9002 - val_loss: 0.5813 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3224/10000
#
# Epoch 03224: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.9020 - val_loss: 0.5826 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3225/10000
#
# Epoch 03225: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3496 - accuracy: 0.9002 - val_loss: 0.5825 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3226/10000
#
# Epoch 03226: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3495 - accuracy: 0.9002 - val_loss: 0.5812 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3227/10000
#
# Epoch 03227: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3496 - accuracy: 0.9020 - val_loss: 0.5829 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3228/10000
#
# Epoch 03228: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.8984 - val_loss: 0.5808 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3229/10000
#
# Epoch 03229: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.9020 - val_loss: 0.5825 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3230/10000
#
# Epoch 03230: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3495 - accuracy: 0.8984 - val_loss: 0.5811 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3231/10000
#
# Epoch 03231: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.9002 - val_loss: 0.5809 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3232/10000
#
# Epoch 03232: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.8984 - val_loss: 0.5816 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3233/10000
#
# Epoch 03233: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.9002 - val_loss: 0.5800 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3234/10000
#
# Epoch 03234: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3494 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3235/10000
#
# Epoch 03235: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3495 - accuracy: 0.8984 - val_loss: 0.5800 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3236/10000
#
# Epoch 03236: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.9002 - val_loss: 0.5804 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3237/10000
#
# Epoch 03237: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3492 - accuracy: 0.8984 - val_loss: 0.5803 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3238/10000
#
# Epoch 03238: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.9002 - val_loss: 0.5790 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3239/10000
#
# Epoch 03239: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.9038 - val_loss: 0.5806 - val_accuracy: 0.8523 - 31ms/epoch - 31ms/step
# Epoch 3240/10000
#
# Epoch 03240: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.9020 - val_loss: 0.5784 - val_accuracy: 0.8565 - 62ms/epoch - 62ms/step
# Epoch 3241/10000
#
# Epoch 03241: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3492 - accuracy: 0.9038 - val_loss: 0.5799 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3242/10000
#
# Epoch 03242: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.9002 - val_loss: 0.5793 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3243/10000
#
# Epoch 03243: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3489 - accuracy: 0.9002 - val_loss: 0.5789 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3244/10000
#
# Epoch 03244: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3489 - accuracy: 0.9002 - val_loss: 0.5806 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3245/10000
#
# Epoch 03245: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.9020 - val_loss: 0.5782 - val_accuracy: 0.8565 - 29ms/epoch - 29ms/step
# Epoch 3246/10000
#
# Epoch 03246: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3492 - accuracy: 0.9038 - val_loss: 0.5806 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3247/10000
#
# Epoch 03247: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3492 - accuracy: 0.9020 - val_loss: 0.5782 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3248/10000
#
# Epoch 03248: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3490 - accuracy: 0.9038 - val_loss: 0.5791 - val_accuracy: 0.8565 - 41ms/epoch - 41ms/step
# Epoch 3249/10000
#
# Epoch 03249: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3250/10000
#
# Epoch 03250: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.9002 - val_loss: 0.5785 - val_accuracy: 0.8565 - 44ms/epoch - 44ms/step
# Epoch 3251/10000
#
# Epoch 03251: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3489 - accuracy: 0.9002 - val_loss: 0.5807 - val_accuracy: 0.8523 - 31ms/epoch - 31ms/step
# Epoch 3252/10000
#
# Epoch 03252: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.8984 - val_loss: 0.5782 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3253/10000
#
# Epoch 03253: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.9020 - val_loss: 0.5798 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3254/10000
#
# Epoch 03254: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.9002 - val_loss: 0.5786 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3255/10000
#
# Epoch 03255: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.9002 - val_loss: 0.5785 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3256/10000
#
# Epoch 03256: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3487 - accuracy: 0.9002 - val_loss: 0.5800 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3257/10000
#
# Epoch 03257: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.9002 - val_loss: 0.5784 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3258/10000
#
# Epoch 03258: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.9038 - val_loss: 0.5800 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3259/10000
#
# Epoch 03259: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3487 - accuracy: 0.9002 - val_loss: 0.5781 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3260/10000
#
# Epoch 03260: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.9002 - val_loss: 0.5790 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3261/10000
#
# Epoch 03261: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.9002 - val_loss: 0.5791 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3262/10000
#
# Epoch 03262: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.9002 - val_loss: 0.5784 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3263/10000
#
# Epoch 03263: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3487 - accuracy: 0.9038 - val_loss: 0.5800 - val_accuracy: 0.8523 - 27ms/epoch - 27ms/step
# Epoch 3264/10000
#
# Epoch 03264: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.9002 - val_loss: 0.5783 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3265/10000
#
# Epoch 03265: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8565 - 49ms/epoch - 49ms/step
# Epoch 3266/10000
#
# Epoch 03266: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.9002 - val_loss: 0.5794 - val_accuracy: 0.8565 - 28ms/epoch - 28ms/step
# Epoch 3267/10000
#
# Epoch 03267: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.8984 - val_loss: 0.5790 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3268/10000
#
# Epoch 03268: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3486 - accuracy: 0.9020 - val_loss: 0.5801 - val_accuracy: 0.8481 - 35ms/epoch - 35ms/step
# Epoch 3269/10000
#
# Epoch 03269: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.9002 - val_loss: 0.5778 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3270/10000
#
# Epoch 03270: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.9038 - val_loss: 0.5799 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3271/10000
#
# Epoch 03271: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9002 - val_loss: 0.5788 - val_accuracy: 0.8565 - 43ms/epoch - 43ms/step
# Epoch 3272/10000
#
# Epoch 03272: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3485 - accuracy: 0.8984 - val_loss: 0.5791 - val_accuracy: 0.8565 - 45ms/epoch - 45ms/step
# Epoch 3273/10000
#
# Epoch 03273: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9020 - val_loss: 0.5803 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3274/10000
#
# Epoch 03274: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9002 - val_loss: 0.5784 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3275/10000
#
# Epoch 03275: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9020 - val_loss: 0.5806 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3276/10000
#
# Epoch 03276: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9002 - val_loss: 0.5789 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3277/10000
#
# Epoch 03277: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3484 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8565 - 26ms/epoch - 26ms/step
# Epoch 3278/10000
#
# Epoch 03278: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3483 - accuracy: 0.9020 - val_loss: 0.5802 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3279/10000
#
# Epoch 03279: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3482 - accuracy: 0.9002 - val_loss: 0.5786 - val_accuracy: 0.8565 - 41ms/epoch - 41ms/step
# Epoch 3280/10000
#
# Epoch 03280: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3483 - accuracy: 0.9020 - val_loss: 0.5808 - val_accuracy: 0.8481 - 41ms/epoch - 41ms/step
# Epoch 3281/10000
#
# Epoch 03281: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3483 - accuracy: 0.9002 - val_loss: 0.5783 - val_accuracy: 0.8565 - 28ms/epoch - 28ms/step
# Epoch 3282/10000
#
# Epoch 03282: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3483 - accuracy: 0.9020 - val_loss: 0.5798 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3283/10000
#
# Epoch 03283: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3482 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3284/10000
#
# Epoch 03284: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9002 - val_loss: 0.5794 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3285/10000
#
# Epoch 03285: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9002 - val_loss: 0.5808 - val_accuracy: 0.8481 - 34ms/epoch - 34ms/step
# Epoch 3286/10000
#
# Epoch 03286: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9002 - val_loss: 0.5787 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3287/10000
#
# Epoch 03287: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3482 - accuracy: 0.9020 - val_loss: 0.5805 - val_accuracy: 0.8481 - 33ms/epoch - 33ms/step
# Epoch 3288/10000
#
# Epoch 03288: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9002 - val_loss: 0.5792 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3289/10000
#
# Epoch 03289: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9002 - val_loss: 0.5792 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3290/10000
#
# Epoch 03290: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9002 - val_loss: 0.5803 - val_accuracy: 0.8481 - 34ms/epoch - 34ms/step
# Epoch 3291/10000
#
# Epoch 03291: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9002 - val_loss: 0.5787 - val_accuracy: 0.8565 - 40ms/epoch - 40ms/step
# Epoch 3292/10000
#
# Epoch 03292: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9020 - val_loss: 0.5814 - val_accuracy: 0.8481 - 35ms/epoch - 35ms/step
# Epoch 3293/10000
#
# Epoch 03293: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9002 - val_loss: 0.5788 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3294/10000
#
# Epoch 03294: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3481 - accuracy: 0.9038 - val_loss: 0.5805 - val_accuracy: 0.8481 - 55ms/epoch - 55ms/step
# Epoch 3295/10000
#
# Epoch 03295: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9002 - val_loss: 0.5792 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3296/10000
#
# Epoch 03296: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.9020 - val_loss: 0.5792 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3297/10000
#
# Epoch 03297: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.9002 - val_loss: 0.5802 - val_accuracy: 0.8481 - 43ms/epoch - 43ms/step
# Epoch 3298/10000
#
# Epoch 03298: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.9002 - val_loss: 0.5790 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3299/10000
#
# Epoch 03299: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.9002 - val_loss: 0.5813 - val_accuracy: 0.8481 - 32ms/epoch - 32ms/step
# Epoch 3300/10000
#
# Epoch 03300: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9002 - val_loss: 0.5794 - val_accuracy: 0.8565 - 46ms/epoch - 46ms/step
# Epoch 3301/10000
#
# Epoch 03301: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3480 - accuracy: 0.9020 - val_loss: 0.5805 - val_accuracy: 0.8481 - 39ms/epoch - 39ms/step
# Epoch 3302/10000
#
# Epoch 03302: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.9002 - val_loss: 0.5792 - val_accuracy: 0.8523 - 47ms/epoch - 47ms/step
# Epoch 3303/10000
#
# Epoch 03303: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3478 - accuracy: 0.9020 - val_loss: 0.5794 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3304/10000
#
# Epoch 03304: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3478 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8523 - 39ms/epoch - 39ms/step
# Epoch 3305/10000
#
# Epoch 03305: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3477 - accuracy: 0.9002 - val_loss: 0.5793 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3306/10000
#
# Epoch 03306: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3477 - accuracy: 0.9002 - val_loss: 0.5803 - val_accuracy: 0.8481 - 33ms/epoch - 33ms/step
# Epoch 3307/10000
#
# Epoch 03307: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3478 - accuracy: 0.9002 - val_loss: 0.5796 - val_accuracy: 0.8565 - 26ms/epoch - 26ms/step
# Epoch 3308/10000
#
# Epoch 03308: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3478 - accuracy: 0.9020 - val_loss: 0.5799 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3309/10000
#
# Epoch 03309: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3477 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3310/10000
#
# Epoch 03310: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8523 - 35ms/epoch - 35ms/step
# Epoch 3311/10000
#
# Epoch 03311: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9020 - val_loss: 0.5799 - val_accuracy: 0.8523 - 39ms/epoch - 39ms/step
# Epoch 3312/10000
#
# Epoch 03312: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3477 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3313/10000
#
# Epoch 03313: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9020 - val_loss: 0.5800 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3314/10000
#
# Epoch 03314: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3315/10000
#
# Epoch 03315: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3316/10000
#
# Epoch 03316: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5799 - val_accuracy: 0.8523 - 37ms/epoch - 37ms/step
# Epoch 3317/10000
#
# Epoch 03317: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5796 - val_accuracy: 0.8523 - 40ms/epoch - 40ms/step
# Epoch 3318/10000
#
# Epoch 03318: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5800 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3319/10000
#
# Epoch 03319: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5796 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3320/10000
#
# Epoch 03320: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5799 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3321/10000
#
# Epoch 03321: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3322/10000
#
# Epoch 03322: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3323/10000
#
# Epoch 03323: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3324/10000
#
# Epoch 03324: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5793 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3325/10000
#
# Epoch 03325: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9020 - val_loss: 0.5810 - val_accuracy: 0.8439 - 35ms/epoch - 35ms/step
# Epoch 3326/10000
#
# Epoch 03326: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5786 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 3327/10000
#
# Epoch 03327: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9056 - val_loss: 0.5812 - val_accuracy: 0.8481 - 36ms/epoch - 36ms/step
# Epoch 3328/10000
#
# Epoch 03328: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5786 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 3329/10000
#
# Epoch 03329: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9056 - val_loss: 0.5811 - val_accuracy: 0.8481 - 35ms/epoch - 35ms/step
# Epoch 3330/10000
#
# Epoch 03330: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 3331/10000
#
# Epoch 03331: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9020 - val_loss: 0.5809 - val_accuracy: 0.8481 - 36ms/epoch - 36ms/step
# Epoch 3332/10000
#
# Epoch 03332: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5801 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3333/10000
#
# Epoch 03333: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9038 - val_loss: 0.5802 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3334/10000
#
# Epoch 03334: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3335/10000
#
# Epoch 03335: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9038 - val_loss: 0.5812 - val_accuracy: 0.8481 - 47ms/epoch - 47ms/step
# Epoch 3336/10000
#
# Epoch 03336: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5795 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3337/10000
#
# Epoch 03337: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9038 - val_loss: 0.5827 - val_accuracy: 0.8439 - 33ms/epoch - 33ms/step
# Epoch 3338/10000
#
# Epoch 03338: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9002 - val_loss: 0.5793 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3339/10000
#
# Epoch 03339: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9056 - val_loss: 0.5818 - val_accuracy: 0.8439 - 31ms/epoch - 31ms/step
# Epoch 3340/10000
#
# Epoch 03340: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9002 - val_loss: 0.5794 - val_accuracy: 0.8565 - 28ms/epoch - 28ms/step
# Epoch 3341/10000
#
# Epoch 03341: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9038 - val_loss: 0.5801 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3342/10000
#
# Epoch 03342: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9020 - val_loss: 0.5807 - val_accuracy: 0.8481 - 40ms/epoch - 40ms/step
# Epoch 3343/10000
#
# Epoch 03343: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9002 - val_loss: 0.5793 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3344/10000
#
# Epoch 03344: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9056 - val_loss: 0.5828 - val_accuracy: 0.8481 - 35ms/epoch - 35ms/step
# Epoch 3345/10000
#
# Epoch 03345: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.9002 - val_loss: 0.5796 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3346/10000
#
# Epoch 03346: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.9056 - val_loss: 0.5820 - val_accuracy: 0.8439 - 38ms/epoch - 38ms/step
# Epoch 3347/10000
#
# Epoch 03347: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3348/10000
#
# Epoch 03348: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9038 - val_loss: 0.5801 - val_accuracy: 0.8565 - 30ms/epoch - 30ms/step
# Epoch 3349/10000
#
# Epoch 03349: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9038 - val_loss: 0.5813 - val_accuracy: 0.8481 - 40ms/epoch - 40ms/step
# Epoch 3350/10000
#
# Epoch 03350: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9002 - val_loss: 0.5794 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3351/10000
#
# Epoch 03351: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9038 - val_loss: 0.5818 - val_accuracy: 0.8481 - 32ms/epoch - 32ms/step
# Epoch 3352/10000
#
# Epoch 03352: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9002 - val_loss: 0.5800 - val_accuracy: 0.8523 - 34ms/epoch - 34ms/step
# Epoch 3353/10000
#
# Epoch 03353: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9020 - val_loss: 0.5806 - val_accuracy: 0.8523 - 53ms/epoch - 53ms/step
# Epoch 3354/10000
#
# Epoch 03354: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9002 - val_loss: 0.5810 - val_accuracy: 0.8481 - 26ms/epoch - 26ms/step
# Epoch 3355/10000
#
# Epoch 03355: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9002 - val_loss: 0.5796 - val_accuracy: 0.8565 - 32ms/epoch - 32ms/step
# Epoch 3356/10000
#
# Epoch 03356: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9056 - val_loss: 0.5829 - val_accuracy: 0.8439 - 33ms/epoch - 33ms/step
# Epoch 3357/10000
#
# Epoch 03357: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 3358/10000
#
# Epoch 03358: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9056 - val_loss: 0.5823 - val_accuracy: 0.8439 - 31ms/epoch - 31ms/step
# Epoch 3359/10000
#
# Epoch 03359: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3472 - accuracy: 0.9002 - val_loss: 0.5802 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3360/10000
#
# Epoch 03360: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9038 - val_loss: 0.5805 - val_accuracy: 0.8523 - 29ms/epoch - 29ms/step
# Epoch 3361/10000
#
# Epoch 03361: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9020 - val_loss: 0.5813 - val_accuracy: 0.8481 - 28ms/epoch - 28ms/step
# Epoch 3362/10000
#
# Epoch 03362: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9020 - val_loss: 0.5795 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3363/10000
#
# Epoch 03363: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9056 - val_loss: 0.5831 - val_accuracy: 0.8439 - 36ms/epoch - 36ms/step
# Epoch 3364/10000
#
# Epoch 03364: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9002 - val_loss: 0.5798 - val_accuracy: 0.8608 - 49ms/epoch - 49ms/step
# Epoch 3365/10000
#
# Epoch 03365: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.9056 - val_loss: 0.5825 - val_accuracy: 0.8439 - 31ms/epoch - 31ms/step
# Epoch 3366/10000
#
# Epoch 03366: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.9002 - val_loss: 0.5807 - val_accuracy: 0.8523 - 27ms/epoch - 27ms/step
# Epoch 3367/10000
#
# Epoch 03367: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9038 - val_loss: 0.5805 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3368/10000
#
# Epoch 03368: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9020 - val_loss: 0.5818 - val_accuracy: 0.8439 - 34ms/epoch - 34ms/step
# Epoch 3369/10000
#
# Epoch 03369: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9002 - val_loss: 0.5797 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 3370/10000
#
# Epoch 03370: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9056 - val_loss: 0.5820 - val_accuracy: 0.8439 - 44ms/epoch - 44ms/step
# Epoch 3371/10000
#
# Epoch 03371: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9002 - val_loss: 0.5801 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3372/10000
#
# Epoch 03372: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.9056 - val_loss: 0.5822 - val_accuracy: 0.8439 - 32ms/epoch - 32ms/step
# Epoch 3373/10000
#
# Epoch 03373: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9002 - val_loss: 0.5809 - val_accuracy: 0.8523 - 36ms/epoch - 36ms/step
# Epoch 3374/10000
#
# Epoch 03374: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.9020 - val_loss: 0.5813 - val_accuracy: 0.8481 - 33ms/epoch - 33ms/step
# Epoch 3375/10000
#
# Epoch 03375: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9020 - val_loss: 0.5816 - val_accuracy: 0.8439 - 55ms/epoch - 55ms/step
# Epoch 3376/10000
#
# Epoch 03376: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.9020 - val_loss: 0.5807 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 3377/10000
#
# Epoch 03377: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.9038 - val_loss: 0.5819 - val_accuracy: 0.8439 - 38ms/epoch - 38ms/step
# Epoch 3378/10000
#
# Epoch 03378: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9002 - val_loss: 0.5806 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3379/10000
#
# Epoch 03379: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.9038 - val_loss: 0.5814 - val_accuracy: 0.8439 - 34ms/epoch - 34ms/step
# Epoch 3380/10000
#
# Epoch 03380: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9020 - val_loss: 0.5810 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3381/10000
#
# Epoch 03381: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9020 - val_loss: 0.5808 - val_accuracy: 0.8523 - 39ms/epoch - 39ms/step
# Epoch 3382/10000
#
# Epoch 03382: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.9038 - val_loss: 0.5829 - val_accuracy: 0.8439 - 37ms/epoch - 37ms/step
# Epoch 3383/10000
#
# Epoch 03383: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9002 - val_loss: 0.5803 - val_accuracy: 0.8565 - 38ms/epoch - 38ms/step
# Epoch 3384/10000
#
# Epoch 03384: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9056 - val_loss: 0.5831 - val_accuracy: 0.8439 - 42ms/epoch - 42ms/step
# Epoch 3385/10000
#
# Epoch 03385: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3469 - accuracy: 0.9002 - val_loss: 0.5800 - val_accuracy: 0.8565 - 27ms/epoch - 27ms/step
# Epoch 3386/10000
#
# Epoch 03386: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9056 - val_loss: 0.5818 - val_accuracy: 0.8439 - 31ms/epoch - 31ms/step
# Epoch 3387/10000
#
# Epoch 03387: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9038 - val_loss: 0.5811 - val_accuracy: 0.8523 - 33ms/epoch - 33ms/step
# Epoch 3388/10000
#
# Epoch 03388: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9020 - val_loss: 0.5814 - val_accuracy: 0.8481 - 34ms/epoch - 34ms/step
# Epoch 3389/10000
#
# Epoch 03389: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8439 - 37ms/epoch - 37ms/step
# Epoch 3390/10000
#
# Epoch 03390: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9020 - val_loss: 0.5809 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 3391/10000
#
# Epoch 03391: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8439 - 30ms/epoch - 30ms/step
# Epoch 3392/10000
#
# Epoch 03392: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9002 - val_loss: 0.5809 - val_accuracy: 0.8565 - 29ms/epoch - 29ms/step
# Epoch 3393/10000
#
# Epoch 03393: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9038 - val_loss: 0.5815 - val_accuracy: 0.8439 - 32ms/epoch - 32ms/step
# Epoch 3394/10000
#
# Epoch 03394: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9038 - val_loss: 0.5816 - val_accuracy: 0.8439 - 34ms/epoch - 34ms/step
# Epoch 3395/10000
#
# Epoch 03395: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9020 - val_loss: 0.5809 - val_accuracy: 0.8523 - 31ms/epoch - 31ms/step
# Epoch 3396/10000
#
# Epoch 03396: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9020 - val_loss: 0.5832 - val_accuracy: 0.8439 - 37ms/epoch - 37ms/step
# Epoch 3397/10000
#
# Epoch 03397: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9002 - val_loss: 0.5807 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3398/10000
#
# Epoch 03398: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9056 - val_loss: 0.5828 - val_accuracy: 0.8439 - 33ms/epoch - 33ms/step
# Epoch 3399/10000
#
# Epoch 03399: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9002 - val_loss: 0.5811 - val_accuracy: 0.8565 - 31ms/epoch - 31ms/step
# Epoch 3400/10000
#
# Epoch 03400: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9038 - val_loss: 0.5814 - val_accuracy: 0.8523 - 32ms/epoch - 32ms/step
# Epoch 3401/10000
#
# Epoch 03401: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.9020 - val_loss: 0.5823 - val_accuracy: 0.8439 - 34ms/epoch - 34ms/step
# Epoch 3402/10000
#
# Epoch 03402: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3465 - accuracy: 0.9002 - val_loss: 0.5807 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 3403/10000
#
# Epoch 03403: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9038 - val_loss: 0.5840 - val_accuracy: 0.8481 - 31ms/epoch - 31ms/step
# Epoch 3404/10000
#
# Epoch 03404: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9002 - val_loss: 0.5807 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 3405/10000
#
# Epoch 03405: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9056 - val_loss: 0.5832 - val_accuracy: 0.8439 - 33ms/epoch - 33ms/step
# Epoch 3406/10000
#
# Epoch 03406: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3467 - accuracy: 0.9002 - val_loss: 0.5808 - val_accuracy: 0.8565 - 53ms/epoch - 53ms/step
# Epoch 3407/10000
#
# Epoch 03407: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9056 - val_loss: 0.5826 - val_accuracy: 0.8481 - 30ms/epoch - 30ms/step
# Epoch 3408/10000
#
# Epoch 03408: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3466 - accuracy: 0.9002 - val_loss: 0.5814 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3409/10000
#
# Epoch 03409: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.9038 - val_loss: 0.5826 - val_accuracy: 0.8439 - 40ms/epoch - 40ms/step
# Epoch 3410/10000
#
# Epoch 03410: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.9020 - val_loss: 0.5821 - val_accuracy: 0.8481 - 30ms/epoch - 30ms/step
# Epoch 3411/10000
#
# Epoch 03411: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3463 - accuracy: 0.9020 - val_loss: 0.5819 - val_accuracy: 0.8481 - 26ms/epoch - 26ms/step
# Epoch 3412/10000
#
# Epoch 03412: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3463 - accuracy: 0.9020 - val_loss: 0.5824 - val_accuracy: 0.8439 - 31ms/epoch - 31ms/step
# Epoch 3413/10000
#
# Epoch 03413: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.9020 - val_loss: 0.5813 - val_accuracy: 0.8523 - 27ms/epoch - 27ms/step
# Epoch 3414/10000
#
# Epoch 03414: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.9038 - val_loss: 0.5822 - val_accuracy: 0.8481 - 38ms/epoch - 38ms/step
# Epoch 3415/10000
#
# Epoch 03415: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3463 - accuracy: 0.9020 - val_loss: 0.5814 - val_accuracy: 0.8523 - 30ms/epoch - 30ms/step
# Epoch 3416/10000
#
# Epoch 03416: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3462 - accuracy: 0.9020 - val_loss: 0.5819 - val_accuracy: 0.8439 - 35ms/epoch - 35ms/step
# Epoch 3417/10000
#
# Epoch 03417: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3462 - accuracy: 0.9038 - val_loss: 0.5821 - val_accuracy: 0.8439 - 35ms/epoch - 35ms/step
# Epoch 3418/10000
#
# ...
# Epoch 4319/10000
#
# Epoch 04319: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3209 - accuracy: 0.9038 - val_loss: 0.6040 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 4320/10000
#
# Epoch 04320: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3209 - accuracy: 0.9056 - val_loss: 0.6053 - val_accuracy: 0.8608 - 54ms/epoch - 54ms/step
# Epoch 4321/10000
#
# Epoch 04321: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3208 - accuracy: 0.9038 - val_loss: 0.6035 - val_accuracy: 0.8565 - 55ms/epoch - 55ms/step
# Epoch 4322/10000
#
# Epoch 04322: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9074 - val_loss: 0.6047 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 4323/10000
#
# Epoch 04323: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3206 - accuracy: 0.9056 - val_loss: 0.6042 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 4324/10000
#
# Epoch 04324: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3206 - accuracy: 0.9074 - val_loss: 0.6043 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 4325/10000
#
# Epoch 04325: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9056 - val_loss: 0.6053 - val_accuracy: 0.8565 - 39ms/epoch - 39ms/step
# Epoch 4326/10000
#
# Epoch 04326: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9093 - val_loss: 0.6041 - val_accuracy: 0.8565 - 27ms/epoch - 27ms/step
# Epoch 4327/10000
#
# Epoch 04327: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9074 - val_loss: 0.6063 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4328/10000
#
# Epoch 04328: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9038 - val_loss: 0.6035 - val_accuracy: 0.8608 - 37ms/epoch - 37ms/step
# Epoch 4329/10000
#
# Epoch 04329: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9074 - val_loss: 0.6062 - val_accuracy: 0.8608 - 42ms/epoch - 42ms/step
# Epoch 4330/10000
#
# Epoch 04330: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.9038 - val_loss: 0.6034 - val_accuracy: 0.8608 - 38ms/epoch - 38ms/step
# Epoch 4331/10000
#
# Epoch 04331: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3205 - accuracy: 0.9074 - val_loss: 0.6051 - val_accuracy: 0.8565 - 33ms/epoch - 33ms/step
# Epoch 4332/10000
#
# Epoch 04332: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.9056 - val_loss: 0.6047 - val_accuracy: 0.8565 - 27ms/epoch - 27ms/step
# Epoch 4333/10000
#
# Epoch 04333: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.9074 - val_loss: 0.6039 - val_accuracy: 0.8565 - 37ms/epoch - 37ms/step
# Epoch 4334/10000
#
# Epoch 04334: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.9074 - val_loss: 0.6063 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 4335/10000
#
# Epoch 04335: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.9038 - val_loss: 0.6040 - val_accuracy: 0.8565 - 34ms/epoch - 34ms/step
# Epoch 4336/10000
#
# Epoch 04336: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3205 - accuracy: 0.9074 - val_loss: 0.6065 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4337/10000
#
# Epoch 04337: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3205 - accuracy: 0.9038 - val_loss: 0.6042 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4338/10000
#
# Epoch 04338: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3205 - accuracy: 0.9074 - val_loss: 0.6061 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4339/10000
#
# Epoch 04339: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3205 - accuracy: 0.9056 - val_loss: 0.6043 - val_accuracy: 0.8608 - 29ms/epoch - 29ms/step
# Epoch 4340/10000
#
# Epoch 04340: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.9074 - val_loss: 0.6055 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4341/10000
#
# Epoch 04341: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9074 - val_loss: 0.6051 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4342/10000
#
# Epoch 04342: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9074 - val_loss: 0.6049 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4343/10000
#
# Epoch 04343: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.9074 - val_loss: 0.6062 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4344/10000
#
# Epoch 04344: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9093 - val_loss: 0.6050 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4345/10000
#
# Epoch 04345: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9074 - val_loss: 0.6068 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4346/10000
#
# Epoch 04346: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3203 - accuracy: 0.9056 - val_loss: 0.6046 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4347/10000
#
# Epoch 04347: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3203 - accuracy: 0.9074 - val_loss: 0.6070 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4348/10000
#
# Epoch 04348: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3203 - accuracy: 0.9038 - val_loss: 0.6042 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4349/10000
#
# Epoch 04349: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9074 - val_loss: 0.6064 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4350/10000
#
# Epoch 04350: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.9074 - val_loss: 0.6051 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4351/10000
#
# Epoch 04351: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3200 - accuracy: 0.9074 - val_loss: 0.6055 - val_accuracy: 0.8565 - 36ms/epoch - 36ms/step
# Epoch 4352/10000
#
# Epoch 04352: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3200 - accuracy: 0.9074 - val_loss: 0.6067 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4353/10000
#
# Epoch 04353: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3200 - accuracy: 0.9093 - val_loss: 0.6050 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4354/10000
#
# Epoch 04354: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.9074 - val_loss: 0.6076 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4355/10000
#
# Epoch 04355: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.9038 - val_loss: 0.6045 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4356/10000
#
# Epoch 04356: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3202 - accuracy: 0.9074 - val_loss: 0.6075 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4357/10000
#
# Epoch 04357: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.9038 - val_loss: 0.6043 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4358/10000
#
# Epoch 04358: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3199 - accuracy: 0.9074 - val_loss: 0.6065 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4359/10000
#
# Epoch 04359: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3198 - accuracy: 0.9074 - val_loss: 0.6055 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4360/10000
#
# Epoch 04360: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3198 - accuracy: 0.9074 - val_loss: 0.6057 - val_accuracy: 0.8565 - 35ms/epoch - 35ms/step
# Epoch 4361/10000
#
# Epoch 04361: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3198 - accuracy: 0.9074 - val_loss: 0.6072 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4362/10000
#
# Epoch 04362: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3199 - accuracy: 0.9074 - val_loss: 0.6051 - val_accuracy: 0.8608 - 39ms/epoch - 39ms/step
# Epoch 4363/10000
#
# Epoch 04363: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3199 - accuracy: 0.9074 - val_loss: 0.6082 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4364/10000
#
# Epoch 04364: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3199 - accuracy: 0.9038 - val_loss: 0.6046 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4365/10000
#
# Epoch 04365: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3199 - accuracy: 0.9074 - val_loss: 0.6078 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4366/10000
#
# Epoch 04366: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3198 - accuracy: 0.9038 - val_loss: 0.6048 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4367/10000
#
# Epoch 04367: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3197 - accuracy: 0.9074 - val_loss: 0.6064 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4368/10000
#
# Epoch 04368: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3196 - accuracy: 0.9074 - val_loss: 0.6063 - val_accuracy: 0.8608 - 38ms/epoch - 38ms/step
# Epoch 4369/10000
#
# Epoch 04369: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3195 - accuracy: 0.9074 - val_loss: 0.6056 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4370/10000
#
# Epoch 04370: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3196 - accuracy: 0.9074 - val_loss: 0.6077 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4371/10000
#
# Epoch 04371: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3197 - accuracy: 0.9056 - val_loss: 0.6055 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4372/10000
#
# Epoch 04372: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3197 - accuracy: 0.9074 - val_loss: 0.6082 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4373/10000
#
# Epoch 04373: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3197 - accuracy: 0.9056 - val_loss: 0.6053 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4374/10000
#
# Epoch 04374: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3196 - accuracy: 0.9074 - val_loss: 0.6078 - val_accuracy: 0.8608 - 39ms/epoch - 39ms/step
# Epoch 4375/10000
#
# Epoch 04375: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3196 - accuracy: 0.9038 - val_loss: 0.6053 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4376/10000
#
# Epoch 04376: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9074 - val_loss: 0.6068 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4377/10000
#
# Epoch 04377: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9074 - val_loss: 0.6066 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4378/10000
#
# Epoch 04378: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.9074 - val_loss: 0.6061 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4379/10000
#
# Epoch 04379: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9074 - val_loss: 0.6078 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4380/10000
#
# Epoch 04380: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9074 - val_loss: 0.6059 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4381/10000
#
# Epoch 04381: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3195 - accuracy: 0.9074 - val_loss: 0.6083 - val_accuracy: 0.8608 - 36ms/epoch - 36ms/step
# Epoch 4382/10000
#
# Epoch 04382: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9056 - val_loss: 0.6053 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4383/10000
#
# Epoch 04383: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.9074 - val_loss: 0.6083 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4384/10000
#
# Epoch 04384: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.9020 - val_loss: 0.6052 - val_accuracy: 0.8608 - 44ms/epoch - 44ms/step
# Epoch 4385/10000
#
# Epoch 04385: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.9074 - val_loss: 0.6074 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4386/10000
#
# Epoch 04386: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9074 - val_loss: 0.6067 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4387/10000
#
# Epoch 04387: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9074 - val_loss: 0.6062 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4388/10000
#
# Epoch 04388: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9074 - val_loss: 0.6084 - val_accuracy: 0.8608 - 51ms/epoch - 51ms/step
# Epoch 4389/10000
#
# Epoch 04389: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9074 - val_loss: 0.6057 - val_accuracy: 0.8608 - 27ms/epoch - 27ms/step
# Epoch 4390/10000
#
# Epoch 04390: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9074 - val_loss: 0.6090 - val_accuracy: 0.8608 - 39ms/epoch - 39ms/step
# Epoch 4391/10000
#
# Epoch 04391: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9038 - val_loss: 0.6057 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4392/10000
#
# Epoch 04392: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9074 - val_loss: 0.6086 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4393/10000
#
# Epoch 04393: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9038 - val_loss: 0.6060 - val_accuracy: 0.8608 - 47ms/epoch - 47ms/step
# Epoch 4394/10000
#
# Epoch 04394: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9074 - val_loss: 0.6077 - val_accuracy: 0.8608 - 37ms/epoch - 37ms/step
# Epoch 4395/10000
#
# Epoch 04395: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3190 - accuracy: 0.9074 - val_loss: 0.6066 - val_accuracy: 0.8608 - 35ms/epoch - 35ms/step
# Epoch 4396/10000
#
# Epoch 04396: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3190 - accuracy: 0.9074 - val_loss: 0.6071 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4397/10000
#
# Epoch 04397: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3190 - accuracy: 0.9074 - val_loss: 0.6076 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4398/10000
#
# Epoch 04398: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3189 - accuracy: 0.9074 - val_loss: 0.6073 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4399/10000
#
# Epoch 04399: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3189 - accuracy: 0.9074 - val_loss: 0.6081 - val_accuracy: 0.8608 - 30ms/epoch - 30ms/step
# Epoch 4400/10000
#
# Epoch 04400: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3189 - accuracy: 0.9074 - val_loss: 0.6069 - val_accuracy: 0.8608 - 31ms/epoch - 31ms/step
# Epoch 4401/10000
#
# Epoch 04401: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3190 - accuracy: 0.9074 - val_loss: 0.6090 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 4402/10000
#
# Epoch 04402: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9038 - val_loss: 0.6061 - val_accuracy: 0.8608 - 32ms/epoch - 32ms/step
# Epoch 4403/10000
#
# Epoch 04403: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.9093 - val_loss: 0.6101 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4404/10000
#
# Epoch 04404: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.9074 - val_loss: 0.6053 - val_accuracy: 0.8608 - 33ms/epoch - 33ms/step
# Epoch 4405/10000
#
# Epoch 04405: val_accuracy did not improve from 0.86498
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.9093 - val_loss: 0.6100 - val_accuracy: 0.8608 - 34ms/epoch - 34ms/step
# Epoch 04405: early stopping

# %%
pre_dnn = model.predict(xte_dnn)
p = np.argmax(pre_dnn, axis=-1)
y = np.argmax(yte_dnn, axis=-1)
accuracy = accuracy_score(p, y)
print(f"best accuracy(DNN model) = {accuracy:2.2f}")
# Out:
# best accuracy(DNN model) = 0.85

# %% [markdown]
# 建立DNN model嘗試與RandomForest model進行比較，但結果較差，且訓練效能也相當差

# %%
import joblib

joblib.dump(gs, "/content/drive/MyDrive/Colab Notebooks/random_forest.joblib")
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/random_forest.joblib']
